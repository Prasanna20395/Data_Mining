# %%
consumer_key = 'DRByKwJWEC0h7GAxS9pfoex6G'
consumer_secret = 'Ev33iqe7h9cdzoKOM0E5cLsKrDbd1uvP2JKx4kdukyEyZIJV76' 
access_token = '1617643046870319107-1I7d3vQTq38rR00Y794OFbEgUQ1slA'
access_token_secret = 'JjCV0xPgK9DvhutSHxEFgth6iogp892KZrc4DFraCJJba'

# %%
import tweepy
from tweepy import OAuthHandler
import pandas as pd

# %%
auth = tweepy.OAuthHandler(
    consumer_key,
    consumer_secret,
    access_token,
    access_token_secret
)
api = tweepy.API(auth)

# %%
tweets = api.home_timeline()
# print(public_tweets)
# for tweet in public_tweets:
#     print(tweet.text)
    
data = []
columns = ['User', 'Time', 'Tweet','Like Count']
for tweet in tweets:
    data.append([tweet.user.screen_name,tweet.created_at,tweet.text,tweet])

df = pd.DataFrame(data, columns = columns)
# df.to_CSV('tweets.csv')
df
# Out:
#     User                      Time  \
# 0   espn 2023-02-04 14:00:01+00:00
# 1    CNN 2023-02-04 13:57:52+00:00
# 2    CNN 2023-02-04 13:43:07+00:00
# 3    CNN 2023-02-04 13:26:03+00:00
# 4    CNN 2023-02-04 13:15:00+00:00
# 5    CNN 2023-02-04 13:14:39+00:00
# 6   CP24 2023-02-04 13:12:26+00:00
# 7   CP24 2023-02-04 12:59:37+00:00
# 8    CNN 2023-02-04 12:58:50+00:00
# 9   CP24 2023-02-04 12:58:23+00:00
# 10   CNN 2023-02-04 12:41:23+00:00
# 11   CNN 2023-02-04 12:25:38+00:00
# 12   CNN 2023-02-04 12:09:27+00:00
# 13  CP24 2023-02-04 12:00:30+00:00
# 14   CNN 2023-02-04 11:53:13+00:00
# 15  CP24 2023-02-04 11:50:09+00:00
# 16   CNN 2023-02-04 11:37:17+00:00
# 17  CP24 2023-02-04 11:32:43+00:00
# 18   CNN 2023-02-04 11:20:56+00:00
# 19   CNN 2023-02-04 11:04:49+00:00
#
#                                                 Tweet  \
# 0   Saturdays are for college hoops 🏀\n\n@BoilerBa...
# 1   Breakfast is getting more expensive. Orange ju...
# 2   Le Le, a 24-year-old male giant panda, died at...
# 3   Exclusive: Justices used personal email accoun...
# 4   Who do you think is going to win the Super Bow...
# 5   An American volunteer aid worker, Pete Reed, w...
# 6   Sri Lanka marks independence anniversary amid ...
# 7   China balloon: Many questions about suspected ...
# 8   Less than two weeks ago, Gautam Adani was the ...
# 9   Indigenous group talks about reporting system ...
# 10  An unopened first-generation iPhone from 2007 ...
# 11  Shrek is love, Shrek is life, Shrek is… missin...
# 12  Should you feel guilty about not tipping? An e...
# 13  Marit Stiles set to officially take over as On...
# 14  For a player who is usually so lethal in front...
# 15  Would you pay $300 a year for quick access to ...
# 16  Italian anti-Mafia police have arrested anothe...
# 17  'It's not bouncing back:' Workers continue to ...
# 18  Five players were ejected after a fight, in wh...
# 19  Former Sex Pistols frontman John Lydon has fai...
#
#                                            Like Count
# 0   Status(_api=<tweepy.api.API object at 0x000002...
# 1   Status(_api=<tweepy.api.API object at 0x000002...
# 2   Status(_api=<tweepy.api.API object at 0x000002...
# 3   Status(_api=<tweepy.api.API object at 0x000002...
# 4   Status(_api=<tweepy.api.API object at 0x000002...
# 5   Status(_api=<tweepy.api.API object at 0x000002...
# 6   Status(_api=<tweepy.api.API object at 0x000002...
# 7   Status(_api=<tweepy.api.API object at 0x000002...
# 8   Status(_api=<tweepy.api.API object at 0x000002...
# 9   Status(_api=<tweepy.api.API object at 0x000002...
# 10  Status(_api=<tweepy.api.API object at 0x000002...
# 11  Status(_api=<tweepy.api.API object at 0x000002...
# 12  Status(_api=<tweepy.api.API object at 0x000002...
# 13  Status(_api=<tweepy.api.API object at 0x000002...
# 14  Status(_api=<tweepy.api.API object at 0x000002...
# 15  Status(_api=<tweepy.api.API object at 0x000002...
# 16  Status(_api=<tweepy.api.API object at 0x000002...
# 17  Status(_api=<tweepy.api.API object at 0x000002...
# 18  Status(_api=<tweepy.api.API object at 0x000002...
# 19  Status(_api=<tweepy.api.API object at 0x000002...

# %%
query = 'Covid'
tweets2 = tweepy.Cursor(api.search_tweets,query,lang="en").items(100)
tweet_data = []
columns = ['Date','User','Tweet','Retweet Count']
for tweet in tweets2:
    tweet_data.append([tweet.created_at,tweet.user.screen_name,tweet.text,tweet.retweet_count])
df = pd.DataFrame(tweet_data,columns = columns)
df
# Out:
#                         Date            User  \
# 0  2023-02-04 14:03:45+00:00     forLisa27_3
# 1  2023-02-04 14:03:44+00:00  Phoenix_Ascent
# 2  2023-02-04 14:03:44+00:00     CheckerFack
# 3  2023-02-04 14:03:44+00:00  BennybearBenny
# 4  2023-02-04 14:03:43+00:00     jondamiller
# ..                       ...             ...
# 95 2023-02-04 14:03:15+00:00  Williamjones00
# 96 2023-02-04 14:03:15+00:00    VishaPhullah
# 97 2023-02-04 14:03:14+00:00     ChuckThrock
# 98 2023-02-04 14:03:14+00:00       sidcelery
# 99 2023-02-04 14:03:13+00:00    crazy_one_85
#
#                                                 Tweet  Retweet Count
# 0   RT @Catlover1121: LISA TOUR \nLISA COVID \nLIS...            814
# 1   RT @stkirsch: Read an article about MDs who ar...           1276
# 2   RT @RWMaloneMD: "'Knew Covid had been engineer...           5933
# 3   @DHShades @healthbyjames did you not hear me s...              0
# 4   @mtracey Good, I hope every single Chinese die...              0
# ..                                                ...            ...
# 95  Low immunity, overwhelmed hospitals fuel Covid...              0
# 96  RT @dr_ianjackson: giving both flu and covid v...              3
# 97  RT @OliviaTroye: Reminder that Trump didn’t wa...            471
# 98  RT @cyrusbiotech: We're excited to see Cyrus's...              3
# 99  @SCMountainGoat Come to north GA. We’ve got tr...              0
#
# [100 rows x 4 columns]
